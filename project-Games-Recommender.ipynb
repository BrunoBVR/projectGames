# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df_games = pd.read_csv("games-data-cleaned.csv")

# %%
df_games.head()
# Out:
#                                    name      platform              r-date  \
# 0  The Legend of Zelda: Ocarina of Time    Nintendo64   November 23, 1998
# 1              Tony Hawk's Pro Skater 2   PlayStation  September 20, 2000
# 2                   Grand Theft Auto IV  PlayStation3      April 29, 2008
# 3                           SoulCalibur     Dreamcast   September 8, 1999
# 4                   Grand Theft Auto IV       Xbox360      April 29, 2008
#
#    score  user score               developer  \
# 0     99        91.0                Nintendo
# 1     98        74.0  NeversoftEntertainment
# 2     98        76.0           RockstarNorth
# 3     98        85.0                   Namco
# 4     98        79.0           RockstarNorth
#
#                                       genre players  critics  users  year  \
# 0                   actionadventure,fantasy       1       22   5749  1998
# 1          sports,alternative,skateboarding       2       19    647  2000
# 2  actionadventure,modern,modern,open-world       1       64   3806  2008
# 3                        action,fighting,3d       2       24    324  1999
# 4  actionadventure,modern,modern,open-world       1       86   3364  2008
#
#    month  day  dow  score_diff                                   genre_list
# 0     11   23  Mon         8.0               ['fantasy', 'actionadventure']
# 1      9   20  Wed        24.0   ['alternative', 'sports', 'skateboarding']
# 2      4   29  Tue        22.0  ['modern', 'actionadventure', 'open-world']
# 3      9    8  Wed        13.0                 ['3d', 'fighting', 'action']
# 4      4   29  Tue        19.0  ['modern', 'actionadventure', 'open-world']

# %% [markdown]
# There is a problem here: the `genre_list` column is now a single string, instead of a list as we wanted from the data cleaning. So, we can quickly redo our process of creating the list.

# %%
df_games = df_games.drop('genre_list', axis = 1)

# %%
df_games['genre_list'] = df_games['genre'].apply(lambda s: list(set(s.split(','))) )

# %%
df_games.head()
# Out:
#                                    name      platform              r-date  \
# 0  The Legend of Zelda: Ocarina of Time    Nintendo64   November 23, 1998
# 1              Tony Hawk's Pro Skater 2   PlayStation  September 20, 2000
# 2                   Grand Theft Auto IV  PlayStation3      April 29, 2008
# 3                           SoulCalibur     Dreamcast   September 8, 1999
# 4                   Grand Theft Auto IV       Xbox360      April 29, 2008
#
#    score  user score               developer  \
# 0     99        91.0                Nintendo
# 1     98        74.0  NeversoftEntertainment
# 2     98        76.0           RockstarNorth
# 3     98        85.0                   Namco
# 4     98        79.0           RockstarNorth
#
#                                       genre players  critics  users  year  \
# 0                   actionadventure,fantasy       1       22   5749  1998
# 1          sports,alternative,skateboarding       2       19    647  2000
# 2  actionadventure,modern,modern,open-world       1       64   3806  2008
# 3                        action,fighting,3d       2       24    324  1999
# 4  actionadventure,modern,modern,open-world       1       86   3364  2008
#
#    month  day  dow  score_diff                             genre_list
# 0     11   23  Mon         8.0             [fantasy, actionadventure]
# 1      9   20  Wed        24.0   [sports, alternative, skateboarding]
# 2      4   29  Tue        22.0  [modern, actionadventure, open-world]
# 3      9    8  Wed        13.0                 [3d, fighting, action]
# 4      4   29  Tue        19.0  [modern, actionadventure, open-world]

# %% [markdown]
# # Simple Recomender - Users based
#
# We will create a simple recommendation list to give the top games based on a metric similar to the **IMDB TOP 250 Movies** score.
#
# Simply using the score of the game is not a great ideia, given it does not consider the popularity of the game (games with very few but passionate users will have a huge user score, but not necessarily a good critic score).
#
# Let's use the IMDB weighted rating formula as a metric:
# $$
# \begin{equation}
# \text Weighted Rating (\bf WR) = \left({{\bf v} \over {\bf v} + {\bf m}} \cdot R\right) + \left({{\bf m} \over {\bf v} + {\bf m}} \cdot C\right)
# \end{equation}
# $$
#
# Where
# * $\rm{v}$ is the number of users;
# * $m$ is the minimum users required to be listed in the recommendation list;
# * $R$ is the average rating of the game;
# * $C$ is the mean score across the whole dataset.
#
# We will begin by creating a dataframe with the necessary columns:

# %%
df_sr = df_games[['name','score','user score', 'critics', 'users', 'platform']]
df_sr.head()
# Out:
#                                    name  score  user score  critics  users  \
# 0  The Legend of Zelda: Ocarina of Time     99        91.0       22   5749
# 1              Tony Hawk's Pro Skater 2     98        74.0       19    647
# 2                   Grand Theft Auto IV     98        76.0       64   3806
# 3                           SoulCalibur     98        85.0       24    324
# 4                   Grand Theft Auto IV     98        79.0       86   3364
#
#        platform
# 0    Nintendo64
# 1   PlayStation
# 2  PlayStation3
# 3     Dreamcast
# 4       Xbox360

# %% [markdown]
# The value of $C$ can be easily calculated as the `mean` of column **user score**.

# %%
C = df_sr['user score'].mean()
print(C)
# Out:
# 64.87750780205083

# %% [markdown]
# The value of $m$ is a hyperparameter which we can tune later. For now, let's use the cutoff as the 95th percentile. That is, $m$ will be the 0.95 quantile:

# %%
m = df_sr['users'].quantile(0.95)
print(m)
# Out:
# 659.8499999999985

# %% [markdown]
# Now we filter the games bellow the cutoff:

# %%
df_cut = df_sr.copy()[df_sr['users'] >= m]

# %% [markdown]
# Having our $C$, $m$ and the filtered set, we can write the function to calculate the weigthed rating:

# %%
# Function that computes the weighted rating of each game
def w_r(d, m=m, C=C):
    v = d['users']
    R = d['user score']
    # Calculation based on the IMDB formula
    return (v/(v+m) * R) + (m/(m+v) * C)

# %% [markdown]
# Now, we can define a new feature column named **rating** to store the result from our IMDB formula.

# %%
# Define a new feature 'rating' and calculate its value with `w_r()`
df_cut['rating'] = df_cut.apply(w_r, axis=1)

# %% [markdown]
# Finally, we can sort in descending order by this new **rating** column and check the result from our simple recommender:

# %%
df_cut = df_cut.sort_values('rating', ascending=False)

df_cut.head(20)
# Out:
#                                             name  score  user score  critics  \
# 110                     The Witcher 3: Wild Hunt     93        94.0       32
# 2270                           Ghost of Tsushima     83        92.0      122
# 69                                    God of War     94        92.0      118
# 215                     The Witcher 3: Wild Hunt     92        92.0       79
# 58                     The Last of Us Remastered     95        92.0       70
# 4565                                GrimGrimoire     79        98.0       39
# 53                                The Last of Us     95        92.0       98
# 10608             Diaries of a Spaceport Janitor     69        97.0        7
# 899                               Counter-Strike     88        92.0       11
# 22                                   Half-Life 2     96        91.0       81
# 418                                       Portal     90        92.0       27
# 59                                      Portal 2     95        91.0       52
# 285                     The Witcher 3: Wild Hunt     91        92.0       13
# 209                              Team Fortress 2     92        91.0       17
# 0           The Legend of Zelda: Ocarina of Time     99        91.0       22
# 259    The Witcher 3: Wild Hunt - Blood and Wine     92        93.0       50
# 193                                   Bloodborne     92        89.0      100
# 858                       Counter-Strike: Source     88        89.0        9
# 574                                  Left 4 Dead     89        91.0       58
# 11682                                    Crystar     67        96.0       13
#
#        users      platform     rating
# 110    17537            PC  92.943967
# 2270   17420  PlayStation4  91.010126
# 69     16298  PlayStation4  90.944632
# 215    15749  PlayStation4  90.909322
# 58     14563  PlayStation4  90.824348
# 4565    2314  PlayStation2  90.650646
# 53     11982  PlayStation3  90.584323
# 10608   2495            PC  90.281447
# 899     7112            PC  89.697231
# 22     10773            PC  89.492333
# 418     5187            PC  88.939074
# 59      7482            PC  88.882923
# 285     4799       XboxOne  88.721512
# 209     6724            PC  88.665591
# 0       5749    Nintendo64  88.310449
# 259     3088            PC  88.048728
# 193    10394  PlayStation4  87.560029
# 858    10108            PC  87.521782
# 574     4071            PC  87.356484
# 11682   1645  PlayStation4  87.090016

# %% [markdown]
# So, these are the 20 best games by the IMDB rating. Let's round this rating for a better visual.

# %%
df_cut['rating'] = round(df_cut['rating'],2)

# %%
df_cut.head(20)
# Out:
#                                             name  score  user score  critics  \
# 110                     The Witcher 3: Wild Hunt     93        94.0       32
# 2270                           Ghost of Tsushima     83        92.0      122
# 69                                    God of War     94        92.0      118
# 215                     The Witcher 3: Wild Hunt     92        92.0       79
# 58                     The Last of Us Remastered     95        92.0       70
# 4565                                GrimGrimoire     79        98.0       39
# 53                                The Last of Us     95        92.0       98
# 10608             Diaries of a Spaceport Janitor     69        97.0        7
# 899                               Counter-Strike     88        92.0       11
# 22                                   Half-Life 2     96        91.0       81
# 418                                       Portal     90        92.0       27
# 59                                      Portal 2     95        91.0       52
# 285                     The Witcher 3: Wild Hunt     91        92.0       13
# 209                              Team Fortress 2     92        91.0       17
# 0           The Legend of Zelda: Ocarina of Time     99        91.0       22
# 259    The Witcher 3: Wild Hunt - Blood and Wine     92        93.0       50
# 193                                   Bloodborne     92        89.0      100
# 858                       Counter-Strike: Source     88        89.0        9
# 574                                  Left 4 Dead     89        91.0       58
# 11682                                    Crystar     67        96.0       13
#
#        users      platform  rating
# 110    17537            PC   92.94
# 2270   17420  PlayStation4   91.01
# 69     16298  PlayStation4   90.94
# 215    15749  PlayStation4   90.91
# 58     14563  PlayStation4   90.82
# 4565    2314  PlayStation2   90.65
# 53     11982  PlayStation3   90.58
# 10608   2495            PC   90.28
# 899     7112            PC   89.70
# 22     10773            PC   89.49
# 418     5187            PC   88.94
# 59      7482            PC   88.88
# 285     4799       XboxOne   88.72
# 209     6724            PC   88.67
# 0       5749    Nintendo64   88.31
# 259     3088            PC   88.05
# 193    10394  PlayStation4   87.56
# 858    10108            PC   87.52
# 574     4071            PC   87.36
# 11682   1645  PlayStation4   87.09

# %%
# Saving this df to a csv
# df_cut.to_csv('df-simple-recommender.csv', index=False)

# %% [markdown]
# # Simple Recomender - Critics Based
#
# We can repeat the whole process, but using the number of critics reviewing the game.

# %%
C = df_sr['score'].mean()
print('C: ',C)

# Let's use the 0.9 quantile for the critics...
m = df_sr['critics'].quantile(0.9)
print('m: ', m)
# Out:
# C:  70.38664734730271
# m:  47.0

# %%
df_cut_cr = df_sr.copy()[df_sr['critics'] >= m]

# %%
# Function that computes the weighted rating of each game
def w_r_cr(d, m=m, C=C):
    v = d['critics']
    R = d['score']
    # Calculation based on the IMDB formula
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
# Define a new feature 'rating' and calculate its value with `w_r_cr()`
df_cut_cr['rating'] = df_cut_cr.apply(w_r_cr, axis=1)

df_cut_cr = df_cut_cr.sort_values('rating', ascending=False)

df_cut_cr['rating'] = round(df_cut_cr['rating'],2)

df_cut_cr.head(20)
# Out:
#                                         name  score  user score  critics  \
# 19                       Super Mario Odyssey     97        89.0      113
# 12   The Legend of Zelda: Breath of the Wild     97        86.0      109
# 15                     Red Dead Redemption 2     97        84.0       99
# 4                        Grand Theft Auto IV     98        79.0       86
# 27                Uncharted 2: Among Thieves     96        88.0      105
# 33                             Mass Effect 2     96        89.0       98
# 6                       Super Mario Galaxy 2     97        91.0       87
# 69                                God of War     94        92.0      118
# 35               The Elder Scrolls V: Skyrim     96        86.0       89
# 25                                  BioShock     96        89.0       88
# 53                            The Last of Us     95        92.0       98
# 60                       Red Dead Redemption     95        90.0       96
# 115                   The Last of Us Part II     93        57.0      121
# 28                           Resident Evil 4     96        92.0       82
# 50                                    Halo 2     95        84.0       91
# 22                               Half-Life 2     96        91.0       81
# 5                         Super Mario Galaxy     97        90.0       73
# 38       The Legend of Zelda: The Wind Waker     96        90.0       80
# 101           Call of Duty: Modern Warfare 2     94        65.0      100
# 163               Uncharted 4: A Thief's End     93        85.0      113
#
#       users      platform  rating
# 19     5546        Switch   89.18
# 12    15873        Switch   88.98
# 15    14315  PlayStation4   88.43
# 4      3364       Xbox360   88.24
# 27     6716  PlayStation3   88.08
# 33     3503       Xbox360   87.70
# 6      2521           Wii   87.67
# 69    16298  PlayStation4   87.27
# 35     3954       Xbox360   87.15
# 25     2572       Xbox360   87.08
# 53    11982  PlayStation3   87.02
# 60     2847       Xbox360   86.91
# 115  146262  PlayStation4   86.67
# 28     1596      GameCube   86.67
# 50     1656          Xbox   86.62
# 22    10773            PC   86.60
# 5      3059           Wii   86.58
# 38     1370      GameCube   86.52
# 101    2957       Xbox360   86.45
# 163   12333  PlayStation4   86.36

# %%
# Saving this df to a csv
# df_cut_cr.to_csv('df-simple-recommender-critics.csv', index=False)

# %% [markdown]
# # Content-Based Recommender

# %%
df_cb = df_games.copy()

df_cb.head()
# Out:
#                                    name      platform              r-date  \
# 0  The Legend of Zelda: Ocarina of Time    Nintendo64   November 23, 1998
# 1              Tony Hawk's Pro Skater 2   PlayStation  September 20, 2000
# 2                   Grand Theft Auto IV  PlayStation3      April 29, 2008
# 3                           SoulCalibur     Dreamcast   September 8, 1999
# 4                   Grand Theft Auto IV       Xbox360      April 29, 2008
#
#    score  user score               developer  \
# 0     99        91.0                Nintendo
# 1     98        74.0  NeversoftEntertainment
# 2     98        76.0           RockstarNorth
# 3     98        85.0                   Namco
# 4     98        79.0           RockstarNorth
#
#                                       genre players  critics  users  year  \
# 0                   actionadventure,fantasy       1       22   5749  1998
# 1          sports,alternative,skateboarding       2       19    647  2000
# 2  actionadventure,modern,modern,open-world       1       64   3806  2008
# 3                        action,fighting,3d       2       24    324  1999
# 4  actionadventure,modern,modern,open-world       1       86   3364  2008
#
#    month  day  dow  score_diff                             genre_list
# 0     11   23  Mon         8.0             [fantasy, actionadventure]
# 1      9   20  Wed        24.0   [sports, alternative, skateboarding]
# 2      4   29  Tue        22.0  [modern, actionadventure, open-world]
# 3      9    8  Wed        13.0                 [3d, fighting, action]
# 4      4   29  Tue        19.0  [modern, actionadventure, open-world]

# %% [markdown]
# Let's clean some columns for later:

# %%
df_cb['platform'] = df_cb['platform'].apply(lambda s: s.lower().replace(' ',''))
df_cb['developer'] = df_cb['developer'].apply(lambda s: s.lower().replace(' ',''))
df_cb.head()
# Out:
#                                    name      platform              r-date  \
# 0  The Legend of Zelda: Ocarina of Time    nintendo64   November 23, 1998
# 1              Tony Hawk's Pro Skater 2   playstation  September 20, 2000
# 2                   Grand Theft Auto IV  playstation3      April 29, 2008
# 3                           SoulCalibur     dreamcast   September 8, 1999
# 4                   Grand Theft Auto IV       xbox360      April 29, 2008
#
#    score  user score               developer  \
# 0     99        91.0                nintendo
# 1     98        74.0  neversoftentertainment
# 2     98        76.0           rockstarnorth
# 3     98        85.0                   namco
# 4     98        79.0           rockstarnorth
#
#                                       genre players  critics  users  year  \
# 0                   actionadventure,fantasy       1       22   5749  1998
# 1          sports,alternative,skateboarding       2       19    647  2000
# 2  actionadventure,modern,modern,open-world       1       64   3806  2008
# 3                        action,fighting,3d       2       24    324  1999
# 4  actionadventure,modern,modern,open-world       1       86   3364  2008
#
#    month  day  dow  score_diff                             genre_list
# 0     11   23  Mon         8.0             [fantasy, actionadventure]
# 1      9   20  Wed        24.0   [sports, alternative, skateboarding]
# 2      4   29  Tue        22.0  [modern, actionadventure, open-world]
# 3      9    8  Wed        13.0                 [3d, fighting, action]
# 4      4   29  Tue        19.0  [modern, actionadventure, open-world]

# %% [markdown]
# As we will use string vectorization later, let's convert year to string:

# %%
df_cb['year'] = df_cb['year'].apply(lambda s: str(s) )

# %% [markdown]
# Let's modify the players column to include it in the soup bellow:

# %%
df_cb['players'] = df_cb['players'].apply(lambda s: str(s)+'players' )

# %% [markdown]
# Some games appear in more than one platform, let's rename the ones that do to account for the platform (we want unique names in the **name** column).

# %%
df_cb['duplicate'] = df_cb['name'].duplicated(keep=False)

# %%
def rename_game(x):
    if x['duplicate']:
        return x['name']+'-'+x['platform']
    else:
        return x['name']

# %%
df_cb['name'] = df_cb.apply(rename_game, axis = 1)

# %%
df_cb.head()
# Out:
#                                    name      platform              r-date  \
# 0  The Legend of Zelda: Ocarina of Time    nintendo64   November 23, 1998
# 1  Tony Hawk's Pro Skater 2-playstation   playstation  September 20, 2000
# 2      Grand Theft Auto IV-playstation3  playstation3      April 29, 2008
# 3                 SoulCalibur-dreamcast     dreamcast   September 8, 1999
# 4           Grand Theft Auto IV-xbox360       xbox360      April 29, 2008
#
#    score  user score               developer  \
# 0     99        91.0                nintendo
# 1     98        74.0  neversoftentertainment
# 2     98        76.0           rockstarnorth
# 3     98        85.0                   namco
# 4     98        79.0           rockstarnorth
#
#                                       genre   players  critics  users  year  \
# 0                   actionadventure,fantasy  1players       22   5749  1998
# 1          sports,alternative,skateboarding  2players       19    647  2000
# 2  actionadventure,modern,modern,open-world  1players       64   3806  2008
# 3                        action,fighting,3d  2players       24    324  1999
# 4  actionadventure,modern,modern,open-world  1players       86   3364  2008
#
#    month  day  dow  score_diff                             genre_list  \
# 0     11   23  Mon         8.0             [fantasy, actionadventure]
# 1      9   20  Wed        24.0   [sports, alternative, skateboarding]
# 2      4   29  Tue        22.0  [modern, actionadventure, open-world]
# 3      9    8  Wed        13.0                 [3d, fighting, action]
# 4      4   29  Tue        19.0  [modern, actionadventure, open-world]
#
#    duplicate
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True

# %% [markdown]
# Create a **soup** column merging all content in the features as list columns just created:

# %%
def create_soup(x):
    return ' '.join(x['genre_list']) + ' ' + x['platform'] + ' ' + x['developer'] + ' ' + x['year']+ ' ' + x['players']

# %%
df_cb['soup'] = df_cb.apply(create_soup, axis = 1)

# %%
df_cb['soup'].head(2)
# Out:
# 0    fantasy actionadventure nintendo64 nintendo 19...
# 1    sports alternative skateboarding playstation n...
# Name: soup, dtype: object

# %%
# Import CountVectorizer and create the count matrix
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(df_cb['soup'])

# %%
count_matrix.shape
# Out:
# (17944, 4121)

# %%
# Compute the Cosine Similarity matrix based on the count_matrix
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %%
# Reset index of your main DataFrame and construct reverse mapping
df_cb = df_cb.reset_index()
indices = pd.Series(df_cb.index, index=df_cb['name'])

# %%
# Function that takes in game name as input and outputs most similar games
def get_recommendations(name, num_of_recs = 10, cosine_sim=cosine_sim):
    # Get the index of the game that matches the title
    idx = indices[name]

    # Get the pairwsie similarity scores of all games with that games
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the games based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar games
    sim_scores = sim_scores[1:num_of_recs+1]

    # Get the game indices
    game_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar games
    return df_cb[['name','platform','year']].iloc[game_indices]

# %% [markdown]
# Now, we can use our function to get the top 10 recommendations on a given game.
# Let's get recommendations for `Super Smash Bros. Ultimate`:

# %%
get_recommendations('Super Smash Bros. Ultimate',10, cosine_sim)
# Out:
#                                               name platform  year
# 12702                             Kirby Fighters 2   switch  2020
# 988                    Dragon Ball FighterZ-switch   switch  2018
# 4952             BlazBlue: Cross Tag Battle-switch   switch  2018
# 7138                               Blade Strangers   switch  2018
# 14552         SNK Heroines: Tag Team Frenzy-switch   switch  2018
# 7452                                 Pocket Rumble   switch  2018
# 842                            Super Mario Maker 2   switch  2019
# 1001                          Guacamelee! 2-switch   switch  2018
# 1453   BlazBlue: Central Fiction - Special Edition   switch  2019
# 4268                 Skullgirls: 2nd Encore-switch   switch  2019

# %%
# Saving the df as csv
# df_cb.to_csv('games-recommender.csv',index=False)
